# %%
import numpy as np
import matplotlib.pyplot as plt

from phase import PhaseSolver, PhaseConfig

def correct(frame, mask):
    ys, xs = np.where(mask)
    corr = frame.astype(float).copy()
    for y, x in zip(ys, xs):
        nb  = frame[max(0,y-1):y+2, max(0,x-1):x+2]
        nbm = mask [max(0,y-1):y+2, max(0,x-1):x+2]
        good = nb[~nbm]
        if good.size: corr[y,x] = np.median(good)
    return corr

N = 20

# %% [markdown]
# # Exposure 200 ms

# %%
# Read dark frames
data_dark_200 = np.load("../../data/dark_200_20260907_134836.npz")
stack_dark_200 = data_dark_200['stack'][0]

# %%
# Find and correct for hot pixels
frames = stack_dark_200            # (N,H,W), same gain+exposure as your data

m = frames.mean(0)                 # per-pixel mean  -> high dark current
s = frames.std(0)                  # per-pixel std   -> RTS/flicker

def rob(x, k=5):                   # robust threshold, unbiased by outliers
    med = np.median(x)
    mad = np.median(np.abs(x-med))*1.4826
    return np.abs(x-med) >= k*mad

mask = rob(m) | rob(s)             # (H,W) bool, True = hot
print(100*mask.mean(), "% hot")

stack_dark_200_corr = np.stack([correct(stack_dark_200[n], mask) for n in range(len(stack_dark_200))])
stack_dark_200_ref = stack_dark_200_corr.mean(axis=0)
# Out:
# 0.10300275482093664 % hot

# %%
# Read ref bright frames
data_ref_bright_200 = np.load("../../data/piezo_ref_bright_200_20260907_134427.npz")
stack_ref_bright_200 = data_ref_bright_200['stack'][0][:N]

# %%
# Read ref bright frames
data_sample_bright_200 = np.load("../../data/piezo_sample_bright_200_20260907_135232.npz")
stack_sample_bright_200 = data_sample_bright_200['stack'][0][:N]

# %%
# Correct for hot pixels and subtract dark
stack_ref_bright_200_corr = np.stack([correct(stack_ref_bright_200[n], mask) for n in range(len(stack_ref_bright_200))])
stack_ref_bright_200_corr = np.maximum(stack_ref_bright_200_corr - stack_dark_200_ref, 0)

stack_sample_bright_200_corr = np.stack([correct(stack_sample_bright_200[n], mask) for n in range(len(stack_ref_bright_200))])
stack_sample_bright_200_corr = np.maximum(stack_sample_bright_200_corr - stack_dark_200_ref, 0)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(stack_ref_bright_200_corr[0,1000])
plt.plot(stack_ref_bright_200_corr[3,1000])

plt.subplot(122)
plt.plot(stack_sample_bright_200_corr[0,1000])
plt.plot(stack_sample_bright_200_corr[3,1000])

# %%
# Compute noise
sigma_ref_n = np.sqrt(stack_ref_bright_200_corr*2.6596) / 2.6596    # (N,P), gain=100
sigma_ref_pixel = np.sqrt((sigma_ref_n**2).mean(0))          # (P,)

rms_ref_bright_200 = np.sqrt((sigma_ref_pixel**2).mean())
noise_floor_ref_bright_200 = np.sqrt((sigma_ref_pixel**2).mean()) / stack_ref_bright_200_corr.std()

print(f"RMS noise ref: {rms_ref_bright_200}")
print(f"Noise floor ref: {noise_floor_ref_bright_200}")

sigma_sample_n = np.sqrt(stack_sample_bright_200_corr*2.6596) / 2.6596    # (N,P), gain=100
sigma_sample_pixel = np.sqrt((sigma_sample_n**2).mean(0))          # (P,)

rms_sample_bright_200 = np.sqrt((sigma_sample_pixel**2).mean())
noise_floor_sample_bright_200 = np.sqrt((sigma_sample_pixel**2).mean()) / stack_sample_bright_200_corr.std()

print(f"RMS noise sample: {rms_sample_bright_200}")
print(f"Noise floor sample: {noise_floor_sample_bright_200}")
# Out:
# RMS noise ref: 9.146177491361264
# Noise floor ref: 0.08319467568942124
# RMS noise sample: 8.364947850460425
# Noise floor sample: 0.08804754637711171

# %%
iters = 30
tol = 1e-4
refine_iters = 10
refine_tol = 1e-4

results_ref = {}
for degree in (0,1,2,3,4):
    cfg_d = PhaseConfig.from_yaml("phase_config.yaml")
    cfg_d.use_alpha = True
    cfg_d.gain_mode = "joint"
    cfg_d.precise_reduce = False
    cfg_d.method_kwargs.update(iters=iters, tol=tol, degree=degree,
                                refine_iters=refine_iters, refine_tol=refine_tol)
    solver_d = PhaseSolver(cfg_d)
    solver_d.fit(stack_ref_bright_200_corr)
    results_ref[degree] = solver_d
    mp = solver_d.method_param_
    print(f"degree={degree} converged={mp.refine_converged}  reconstruction_error={solver_d.reconstruction_error_:.4f}  "
          f"kappa_fit={mp.kappa_fit:.3g}  refine_iters_run={mp.refine_iters_run}  "
          f"rms_frac_history={[f'{x:.5f}' for x in mp.rms_frac_history]}")
# Out:
# degree=0 converged=False  reconstruction_error=16.2734  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# degree=1 converged=True  reconstruction_error=11.2359  kappa_fit=1.31  refine_iters_run=5  rms_frac_history=['0.10242', '0.09826', '0.09728', '0.09697', '0.09689']
# degree=2 converged=True  reconstruction_error=9.1440  kappa_fit=1.7  refine_iters_run=5  rms_frac_history=['0.08869', '0.08212', '0.08071', '0.08040', '0.08034']
# degree=3 converged=True  reconstruction_error=8.9537  kappa_fit=3.33  refine_iters_run=5  rms_frac_history=['0.08745', '0.08068', '0.07928', '0.07898', '0.07892']
# degree=4 converged=True  reconstruction_error=8.9343  kappa_fit=3.8  refine_iters_run=5  rms_frac_history=['0.08712', '0.08053', '0.07915', '0.07885', '0.07879']

# %%
iters = 30
tol = 1e-4
refine_iters = 10
refine_tol = 1e-4

results_sample = {}
for degree in (0,1,2,3,4):
    cfg_d = PhaseConfig.from_yaml("phase_config.yaml")
    cfg_d.use_alpha = True
    cfg_d.gain_mode = "joint"
    cfg_d.precise_reduce = False
    cfg_d.method_kwargs.update(iters=iters, tol=tol, degree=degree,
                                refine_iters=refine_iters, refine_tol=refine_tol)
    solver_d = PhaseSolver(cfg_d)
    solver_d.fit(stack_sample_bright_200_corr)
    results_sample[degree] = solver_d
    mp = solver_d.method_param_
    print(f"degree={degree} converged={mp.refine_converged}  reconstruction_error={solver_d.reconstruction_error_:.4f}  "
          f"kappa_fit={mp.kappa_fit:.3g}  refine_iters_run={mp.refine_iters_run}  "
          f"rms_frac_history={[f'{x:.5f}' for x in mp.rms_frac_history]}")
# Out:
# degree=0 converged=False  reconstruction_error=16.4575  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# degree=1 converged=True  reconstruction_error=9.6469  kappa_fit=1.15  refine_iters_run=6  rms_frac_history=['0.10683', '0.09980', '0.09749', '0.09702', '0.09689', '0.09685']
# degree=2 converged=True  reconstruction_error=8.3902  kappa_fit=2.18  refine_iters_run=6  rms_frac_history=['0.09693', '0.09263', '0.08638', '0.08544', '0.08524', '0.08518']
# degree=3 converged=True  reconstruction_error=8.1736  kappa_fit=3.67  refine_iters_run=6  rms_frac_history=['0.09537', '0.09082', '0.08450', '0.08358', '0.08339', '0.08334']
# degree=4 converged=True  reconstruction_error=8.1428  kappa_fit=5.29  refine_iters_run=6  rms_frac_history=['0.09434', '0.08985', '0.08425', '0.08331', '0.08312', '0.08308']

# %%
degree_arr = np.array([0, 1, 2, 3, 4])
plt.plot(degree_arr, [results_ref[deg].reconstruction_error_ for deg in degree_arr], '.-', color="tab:blue", label='glass')
plt.plot(degree_arr, [results_sample[deg].reconstruction_error_ for deg in degree_arr], '.-', color="tab:orange", label='metasurface')
plt.hlines(rms_ref_bright_200, 0, 4, color='tab:blue', linestyles='--')
plt.hlines(rms_sample_bright_200, 0, 4, color='tab:orange', linestyles='--')
plt.text(0.1,8.6, "Noise floor")
plt.xlabel('Polynomial order')
plt.ylabel('Reconstruction error, RMS')
plt.legend()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(results[0].result_.a[1000], label="aia")
#plt.plot(results[1].result_.a[1000], label="first order")
plt.plot(results[2].result_.a[1000], label="second order")
plt.grid()
plt.legend()
plt.xlim([0, 600])
plt.ylim([170, 220])
plt.xlabel('Pixels')
plt.ylabel('a')

plt.subplot(122)
plt.plot(results[0].result_.b[1000])
#plt.plot(results[1].result_.b[1000])
plt.plot(results[2].result_.b[1000])
plt.grid()
plt.xlabel('Pixels')
plt.ylabel('b')

plt.xlim([0, 600])
plt.ylim([100, 160])

plt.tight_layout()

# %%
num_range = np.arange(start=5, stop=21)
iters = 30
tol = 1e-4
refine_iters = 10
refine_tol = 1e-4

cfg_d = PhaseConfig.from_yaml("phase_config.yaml")
cfg_d.use_alpha = True
cfg_d.gain_mode = "joint"
cfg_d.method_kwargs.update(iters=iters, tol=tol, degree=2,
                            refine_iters=refine_iters, refine_tol=refine_tol)

results_ref = {}
for num in num_range:
    solver_d = PhaseSolver(cfg_d)
    solver_d.fit(stack_ref_bright_200_corr[:num])
    results_ref[num] = solver_d
    mp = solver_d.method_param_
    print(f"num={num} converged={mp.refine_converged}  reconstruction_error={solver_d.reconstruction_error_:.4f}  "
            f"kappa_fit={mp.kappa_fit:.3g}  refine_iters_run={mp.refine_iters_run}  "
            f"rms_frac_history={[f'{x:.5f}' for x in mp.rms_frac_history]}")
# Out:
# num=5 converged=True  reconstruction_error=5.9307  kappa_fit=1.7  refine_iters_run=6  rms_frac_history=['0.06252', '0.05442', '0.05117', '0.05041', '0.05021', '0.05015']
# num=6 converged=True  reconstruction_error=6.6788  kappa_fit=1.7  refine_iters_run=6  rms_frac_history=['0.07367', '0.06136', '0.05761', '0.05689', '0.05675', '0.05672']
# num=7 converged=True  reconstruction_error=7.1593  kappa_fit=1.7  refine_iters_run=6  rms_frac_history=['0.07575', '0.06493', '0.06196', '0.06136', '0.06123', '0.06120']
# num=8 converged=True  reconstruction_error=8.1880  kappa_fit=1.77  refine_iters_run=5  rms_frac_history=['0.08814', '0.07473', '0.07164', '0.07112', '0.07104']
# num=9 converged=True  reconstruction_error=8.3779  kappa_fit=1.77  refine_iters_run=5  rms_frac_history=['0.08731', '0.07497', '0.07281', '0.07249', '0.07248']
# num=10 converged=True  reconstruction_error=8.5036  kappa_fit=1.76  refine_iters_run=5  rms_frac_history=['0.08516', '0.07593', '0.07426', '0.07395', '0.07393']
# num=11 converged=True  reconstruction_error=8.6101  kappa_fit=1.78  refine_iters_run=5  rms_frac_history=['0.08565', '0.07744', '0.07575', '0.07550', '0.07547']
# num=12 converged=True  reconstruction_error=8.6890  kappa_fit=1.78  refine_iters_run=5  rms_frac_history=['0.08588', '0.07765', '0.07612', '0.07583', '0.07578']
# num=13 converged=True  reconstruction_error=8.7678  kappa_fit=1.78  refine_iters_run=5  rms_frac_history=['0.08587', '0.07770', '0.07629', '0.07608', '0.07607']
# num=14 converged=True  reconstruction_error=8.8665  kappa_fit=1.76  refine_iters_run=5  rms_frac_history=['0.08453', '0.07772', '0.07677', '0.07660', '0.07659']
# num=15 converged=True  reconstruction_error=8.9776  kappa_fit=1.74  refine_iters_run=5  rms_frac_history=['0.08685', '0.07886', '0.07773', '0.07735', '0.07726']
# num=16 converged=True  reconstruction_error=9.0050  kappa_fit=1.72  refine_iters_run=5  rms_frac_history=['0.08825', '0.08016', '0.07873', '0.07840', '0.07835']
# num=17 converged=True  reconstruction_error=9.0419  kappa_fit=1.72  refine_iters_run=5  rms_frac_history=['0.08926', '0.08125', '0.07962', '0.07927', '0.07919']
# num=18 converged=True  reconstruction_error=9.0645  kappa_fit=1.72  refine_iters_run=5  rms_frac_history=['0.08873', '0.08134', '0.08011', '0.07984', '0.07977']
# num=19 converged=True  reconstruction_error=9.1179  kappa_fit=1.71  refine_iters_run=5  rms_frac_history=['0.08890', '0.08196', '0.08056', '0.08023', '0.08017']
# num=20 converged=True  reconstruction_error=9.1440  kappa_fit=1.7  refine_iters_run=5  rms_frac_history=['0.08869', '0.08212', '0.08071', '0.08040', '0.08034']

# %%
num_range = np.arange(start=5, stop=21)
iters = 30
tol = 1e-4
refine_iters = 10
refine_tol = 1e-4

cfg_d = PhaseConfig.from_yaml("phase_config.yaml")
cfg_d.use_alpha = True
cfg_d.gain_mode = "joint"
cfg_d.method_kwargs.update(iters=iters, tol=tol, degree=2,
                            refine_iters=refine_iters, refine_tol=refine_tol)

results_sample = {}
for num in num_range:
    solver_d = PhaseSolver(cfg_d)
    solver_d.fit(stack_sample_bright_200_corr[:num])
    results_sample[num] = solver_d
    mp = solver_d.method_param_
    print(f"num={num} converged={mp.refine_converged}  reconstruction_error={solver_d.reconstruction_error_:.4f}  "
            f"kappa_fit={mp.kappa_fit:.3g}  refine_iters_run={mp.refine_iters_run}  "
            f"rms_frac_history={[f'{x:.5f}' for x in mp.rms_frac_history]}")
# Out:
# num=5 converged=False  reconstruction_error=5.7266  kappa_fit=2.54  refine_iters_run=10  rms_frac_history=['0.07620', '0.07495', '0.06384', '0.06117', '0.05986', '0.05925', '0.05869', '0.05831', '0.05806', '0.05783']
# num=6 converged=False  reconstruction_error=6.3544  kappa_fit=2.34  refine_iters_run=10  rms_frac_history=['0.08141', '0.08011', '0.07014', '0.06787', '0.06683', '0.06615', '0.06566', '0.06528', '0.06499', '0.06476']
# num=7 converged=False  reconstruction_error=6.8062  kappa_fit=2.28  refine_iters_run=10  rms_frac_history=['0.09115', '0.08503', '0.07521', '0.07208', '0.07105', '0.07027', '0.06977', '0.06946', '0.06926', '0.06915']
# num=8 converged=False  reconstruction_error=7.1020  kappa_fit=2.22  refine_iters_run=10  rms_frac_history=['0.09303', '0.08779', '0.07765', '0.07515', '0.07402', '0.07331', '0.07283', '0.07250', '0.07228', '0.07213']
# num=9 converged=False  reconstruction_error=7.2913  kappa_fit=2.21  refine_iters_run=10  rms_frac_history=['0.09201', '0.08606', '0.07893', '0.07658', '0.07562', '0.07499', '0.07455', '0.07425', '0.07405', '0.07392']
# num=10 converged=False  reconstruction_error=7.4902  kappa_fit=2.23  refine_iters_run=10  rms_frac_history=['0.08972', '0.08519', '0.07851', '0.07759', '0.07697', '0.07655', '0.07626', '0.07604', '0.07588', '0.07577']
# num=11 converged=True  reconstruction_error=7.6482  kappa_fit=2.2  refine_iters_run=9  rms_frac_history=['0.09373', '0.08837', '0.08015', '0.07917', '0.07846', '0.07807', '0.07786', '0.07775', '0.07768']
# num=12 converged=True  reconstruction_error=7.8256  kappa_fit=2.22  refine_iters_run=8  rms_frac_history=['0.09576', '0.09032', '0.08200', '0.08078', '0.08007', '0.07970', '0.07952', '0.07943']
# num=13 converged=True  reconstruction_error=7.8884  kappa_fit=2.21  refine_iters_run=8  rms_frac_history=['0.09377', '0.09043', '0.08224', '0.08113', '0.08064', '0.08039', '0.08026', '0.08020']
# num=14 converged=True  reconstruction_error=7.9993  kappa_fit=2.19  refine_iters_run=8  rms_frac_history=['0.09523', '0.09170', '0.08349', '0.08234', '0.08186', '0.08163', '0.08152', '0.08147']
# num=15 converged=True  reconstruction_error=8.0630  kappa_fit=2.19  refine_iters_run=8  rms_frac_history=['0.09577', '0.09061', '0.08377', '0.08287', '0.08242', '0.08217', '0.08206', '0.08200']
# num=16 converged=True  reconstruction_error=8.1259  kappa_fit=2.19  refine_iters_run=7  rms_frac_history=['0.09549', '0.09078', '0.08424', '0.08325', '0.08289', '0.08274', '0.08269']
# num=17 converged=True  reconstruction_error=8.1463  kappa_fit=2.19  refine_iters_run=7  rms_frac_history=['0.09485', '0.09094', '0.08407', '0.08348', '0.08311', '0.08295', '0.08291']
# num=18 converged=True  reconstruction_error=8.2208  kappa_fit=2.17  refine_iters_run=7  rms_frac_history=['0.09458', '0.09168', '0.08499', '0.08415', '0.08386', '0.08373', '0.08369']
# num=19 converged=True  reconstruction_error=8.3120  kappa_fit=2.17  refine_iters_run=6  rms_frac_history=['0.09646', '0.09165', '0.08606', '0.08475', '0.08457', '0.08449']
# num=20 converged=True  reconstruction_error=8.3902  kappa_fit=2.18  refine_iters_run=6  rms_frac_history=['0.09693', '0.09263', '0.08638', '0.08544', '0.08524', '0.08518']

# %%
num_range = np.arange(start=5, stop=21)
iters = 30
tol = 1e-4
refine_iters = 10
refine_tol = 1e-4

cfg_d = PhaseConfig.from_yaml("phase_config.yaml")
cfg_d.use_alpha = True
cfg_d.gain_mode = "joint"
cfg_d.method_kwargs.update(iters=iters, tol=tol, degree=0,
                            refine_iters=refine_iters, refine_tol=refine_tol)

results_ref0 = {}
for num in num_range:
    solver_d = PhaseSolver(cfg_d)
    solver_d.fit(stack_ref_bright_200_corr[:num])
    results_ref0[num] = solver_d
    mp = solver_d.method_param_
    print(f"num={num} converged={mp.refine_converged}  reconstruction_error={solver_d.reconstruction_error_:.4f}  "
            f"kappa_fit={mp.kappa_fit:.3g}  refine_iters_run={mp.refine_iters_run}  "
            f"rms_frac_history={[f'{x:.5f}' for x in mp.rms_frac_history]}")
# Out:
# num=5 converged=False  reconstruction_error=8.9184  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=6 converged=False  reconstruction_error=11.1689  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=7 converged=False  reconstruction_error=12.0018  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=8 converged=False  reconstruction_error=15.6527  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=9 converged=False  reconstruction_error=16.1861  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=10 converged=False  reconstruction_error=15.9466  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=11 converged=False  reconstruction_error=15.5823  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=12 converged=False  reconstruction_error=15.3788  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=13 converged=False  reconstruction_error=15.3766  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=14 converged=False  reconstruction_error=16.0984  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=15 converged=False  reconstruction_error=16.3520  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=16 converged=False  reconstruction_error=16.2654  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=17 converged=False  reconstruction_error=16.5172  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=18 converged=False  reconstruction_error=16.5854  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=19 converged=False  reconstruction_error=16.5067  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=20 converged=False  reconstruction_error=16.2734  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]

# %%
num_range = np.arange(start=5, stop=21)
iters = 30
tol = 1e-4
refine_iters = 10
refine_tol = 1e-4

cfg_d = PhaseConfig.from_yaml("phase_config.yaml")
cfg_d.use_alpha = True
cfg_d.gain_mode = "joint"
cfg_d.method_kwargs.update(iters=iters, tol=tol, degree=0,
                            refine_iters=refine_iters, refine_tol=refine_tol)

results_sample0 = {}
for num in num_range:
    solver_d = PhaseSolver(cfg_d)
    solver_d.fit(stack_sample_bright_200_corr[:num])
    results_sample0[num] = solver_d
    mp = solver_d.method_param_
    print(f"num={num} converged={mp.refine_converged}  reconstruction_error={solver_d.reconstruction_error_:.4f}  "
            f"kappa_fit={mp.kappa_fit:.3g}  refine_iters_run={mp.refine_iters_run}  "
            f"rms_frac_history={[f'{x:.5f}' for x in mp.rms_frac_history]}")
# Out:
# num=5 converged=False  reconstruction_error=10.0878  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=6 converged=False  reconstruction_error=10.3309  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=7 converged=False  reconstruction_error=12.3601  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=8 converged=False  reconstruction_error=12.6136  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=9 converged=False  reconstruction_error=12.5866  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=10 converged=False  reconstruction_error=13.4459  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=11 converged=False  reconstruction_error=13.7754  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=12 converged=False  reconstruction_error=14.7958  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=13 converged=False  reconstruction_error=14.8221  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=14 converged=False  reconstruction_error=15.5976  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=15 converged=False  reconstruction_error=15.6491  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=16 converged=False  reconstruction_error=15.7025  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=17 converged=False  reconstruction_error=15.5348  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=18 converged=False  reconstruction_error=15.7869  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=19 converged=False  reconstruction_error=16.1399  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# num=20 converged=False  reconstruction_error=16.4575  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]

# %%
plt.plot(num_range, [results_ref[num].reconstruction_error_*np.sqrt(num/(num-3)) for num in num_range],'.-', color="tab:blue", label="glass")
plt.plot(num_range, [results_sample[num].reconstruction_error_*np.sqrt(num/(num-3)) for num in num_range],'.-', color="tab:orange", label="metasurface")
# plt.plot(num_range, [results_ref0[num].reconstruction_error_ for num in num_range],'.-', color="tab:green", label="glass, 0th order")
# plt.plot(num_range, [results_sample0[num].reconstruction_error_ for num in num_range],'.-', color="tab:red", label="metasurface, 0th order")
plt.hlines(rms_ref_bright_200, 5, 20, color='tab:blue', linestyles='--')
plt.hlines(rms_sample_bright_200, 5, 20, color='tab:orange', linestyles='--')
#plt.text(6.5,8.7, "Noise floor")
plt.xlim([5, 20])
plt.legend()
plt.xlabel('Number of piezo steps (frames)')
plt.ylabel('Reconstruction error, RMS')
# Out:
# Text(0, 0.5, 'Reconstruction error, RMS')

# %%
plt.plot(num_range, results_ref[20].result_.g[4:])
plt.plot(num_range[:12], results_ref[16].result_.g[4:])
plt.xlim([5,20])
plt.xlabel('Number of piezo steps (frames)')
plt.ylabel('g')
# Out:
# Text(0, 0.5, 'g')

# %%
plt.imshow(results_ref[15].result_.residual)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 plt.imshow(results_ref[15].result_.residual)
#
# AttributeError: 'PhaseResult' object has no attribute 'residual'

# %%
# Out:
# array([1.0824211 , 1.07633905, 1.05248422, 1.0174602 , 0.92544906,
#        0.97523491, 0.96507862, 0.80121541, 1.01834828, 0.95765768,
#        0.90180914, 1.06201269, 1.07215072, 1.05924754, 1.03852288,
#        0.81014088, 0.87086108, 0.89682929, 0.99932095, 1.00067905])

# %%
def gauss1d(sig, truncate=4.0):
    r = int(truncate*sig + 0.5)
    x = np.arange(-r, r+1)
    k = np.exp(-x**2/(2*sig**2))
    return k / k.sum()

def blur2d(img, sig):
    k = gauss1d(sig)
    H, W = img.shape
    # pad kernel to image size, center it, FFT-convolve (full complex FFT)
    kx = np.zeros(W); kx[:len(k)] = k; kx = np.roll(kx, -(len(k)//2))
    ky = np.zeros(H); ky[:len(k)] = k; ky = np.roll(ky, -(len(k)//2))
    F = np.fft.fft2(img)
    F *= np.fft.fft(ky)[:, None]
    F *= np.fft.fft(kx)[None, :]
    return np.fft.ifft2(F).real

def highpass(img, sig=30):
    return img - blur2d(img, sig)

# %%
from matplotlib.colors import LogNorm
plt.imshow(results_ref[20].a_ - results_ref0[20].a_)
plt.axis('off')
#plt.clim(0, 250)
#plt.clim(50, 400)
# Out:
# (np.float64(-0.5), np.float64(3299.5), np.float64(2199.5), np.float64(-0.5))

# %%
plt.plot((results_ref[20].b_ - results_ref0[20].b_)[100])

# %%
# plt.plot(highpass(results_ref0[20].a_)[1000])
# plt.plot(highpass(results_ref[20].a_)[1000])
plt.plot((results_ref[20].a_ - results_ref0[20].a_)[100])
plt.ylim([-10, 10])
# plt.xlim([500, 1000])
# Out:
# (-10.0, 10.0)

# %%
sig = (results_ref[20].a_ - results_ref0[20].a_)[1000]
def envelope(sig):
    A = np.fft.fft(sig - sig.mean())
    A[len(A)//2:] = 0          # zero negative frequencies -> analytic signal
    A *= 2
    return np.abs(np.fft.ifft(A))

env = envelope(sig)

plt.plot(env)

# %%
from phase.methods.step_field import _poly_basis

degree = 2                                        # pick which results[...] fit to inspect
r = results[degree].result_
mp = results[degree].method_param_
a_, b_, phi_ = r.a, r.b, r.phi
u_ = b_ * np.cos(phi_)
v_ = -b_ * np.sin(phi_)

i = a_.size // 2                                  # a pixel index (flat)
row, col = np.unravel_index(i, a_.shape)
u_i, v_i = u_[row, col], v_[row, col]
b_i = np.hypot(u_i, v_i)

# The degree-2 model's actual per-frame step AT THIS PIXEL, not the plain
# piston delta -- delta_n(x,y) = delta_n + coeffs[:,n] @ basis(x,y)
# (docs/step_field_residuals.md Eq. T1), evaluated at (row, col) only (no
# need to build the full (N,H,W) field for one pixel).
basis = _poly_basis(*a_.shape, degree, np)        # (J, P)
basis_i = basis[:, i]                             # (J,) -- this pixel's basis values
delta_eff = r.delta + mp.coeffs.T @ basis_i        # (N,) -- this pixel's true step

xn = u_i * np.cos(delta_eff) + v_i * np.sin(delta_eff)   # fitted x_n, degree-2 model
yn = u_i * np.sin(delta_eff) - v_i * np.cos(delta_eff)   # quadrature

# Raw experimental x_n at the same pixel, alpha/g-corrected the same way the
# model is (I_n = alpha_n*(a + g_n*(u*cos(delta_n)+v*sin(delta_n)))) -- paired
# with the *model's* yn, since a single-channel intensity sample only gives
# one real number per frame, not an independent (x,y) pair. Points straying
# off the fitted circle are frames where the raw data disagrees with what
# the degree-2 fit predicts -- this is the actual "how good is my model"
# check, now that the reference uses the fitted step field, not the piston.
xn_raw = (stack_ref_bright_200_corr[:, row, col] / r.alpha - a_[row, col]) / r.g

theta = np.linspace(0, 2 * np.pi, 400)
plt.plot(b_i * np.cos(theta), b_i * np.sin(theta), '-', color='0.7', lw=1,
         label='ideal circle (radius b)')
plt.plot(xn, yn, 'o', label=f'fitted (degree={degree})')
plt.plot(xn_raw, yn, 'x', label='raw data')
plt.gca().set_aspect('equal')
plt.xlabel('x_n')
plt.ylabel('y_n')
plt.title(f'Lissajous ellipse at one pixel (degree={degree})')
plt.legend()

# %%
from phase.backend import wrap

xr, yr = xn_raw, yn          # yr still comes from the model -- see the note in the cell above
th = np.arctan2(yr, xr)
rad = np.hypot(xr, yr)

print("radial scatter (amp err):", np.std(rad) / b_i)                # alpha/g miscalibration, noise
print("angular scatter (delta err):", np.std(wrap(th - delta_eff)))  # phase-step (delta_n) error
# Out:
# radial scatter (amp err): 0.03645234782212006
# angular scatter (delta err): 0.05030334454153153

# %% [markdown]
# # Exposure 400 ms

# %%
# Read dark frames
data_dark_400 = np.load("../../data/dark_400_20260907_134803.npz")
stack_dark_400 = data_dark_400['stack'][0]

# %%
# Find and correct for hot pixels
frames = stack_dark_400            # (N,H,W), same gain+exposure as your data

m = frames.mean(0)                 # per-pixel mean  -> high dark current
s = frames.std(0)                  # per-pixel std   -> RTS/flicker

def rob(x, k=5):                   # robust threshold, unbiased by outliers
    med = np.median(x)
    mad = np.median(np.abs(x-med))*1.4826
    return np.abs(x-med) >= k*mad

mask = rob(m) | rob(s)             # (H,W) bool, True = hot
print(100*mask.mean(), "% hot")

stack_dark_400_corr = np.stack([correct(stack_dark_400[n], mask) for n in range(len(stack_dark_400))])
stack_dark_400_ref = stack_dark_400_corr.mean(axis=0)
# Out:
# 0.0750137741046832 % hot

# %%
# Read ref bright frames
data_ref_bright_400 = np.load("../../data/piezo_sample_bright_400_20260907_135149.npz")
stack_ref_bright_400 = data_ref_bright_400['stack'][0]

# %%
# Correct for hot pixels and subtract dark
stack_ref_bright_400_corr = np.stack([correct(stack_ref_bright_400[n], mask) for n in range(len(stack_ref_bright_400))])
stack_ref_bright_400_corr = np.maximum(stack_ref_bright_400_corr - stack_dark_400_ref, 0)

plt.plot(stack_ref_bright_400_corr[0,1000])
plt.plot(stack_ref_bright_400_corr[1,1000])

# %%
# Compute noise
sigma_n = np.sqrt(stack_ref_bright_400_corr*2.6596) / 2.6596    # (N,P), gain=100
sigma_pixel = np.sqrt((sigma_n**2).mean(0))          # (P,)

rms_ref_bright_400 = np.sqrt((sigma_pixel**2).mean())
noise_floor_ref_bright_400 = np.sqrt((sigma_pixel**2).mean()) / stack_ref_bright_400_corr.std()

print(f"RMS noise: {rms_ref_bright_400}")
print(f"Noise floor: {noise_floor_ref_bright_400}")
# Out:
# RMS noise: 11.875078831085956
# Noise floor: 0.061194304980116215

# %%
iters = 30
tol = 1e-4
refine_iters = 20
refine_tol = 1e-4

results = {}
for degree in (0, 1, 2):
    cfg_d = PhaseConfig.from_yaml("phase_config.yaml")
    cfg_d.use_alpha = True
    cfg_d.gain_mode = "joint"
    cfg_d.method_kwargs.update(iters=iters, tol=tol, degree=degree,
                                refine_iters=refine_iters, refine_tol=refine_tol)
    solver_d = PhaseSolver(cfg_d)
    solver_d.fit(stack_ref_bright_400_corr)
    results[degree] = solver_d
    mp = solver_d.method_param_
    print(f"degree={degree} converged={mp.refine_converged}  reconstruction_error={solver_d.reconstruction_error_:.4f}  "
          f"kappa_fit={mp.kappa_fit:.3g}  refine_iters_run={mp.refine_iters_run}  "
          f"rms_frac_history={[f'{x:.5f}' for x in mp.rms_frac_history]}")
# Out:
# degree=0 converged=False  reconstruction_error=24.1711  kappa_fit=nan  refine_iters_run=0  rms_frac_history=[]
# degree=1 converged=True  reconstruction_error=14.1619  kappa_fit=1.17  refine_iters_run=4  rms_frac_history=['0.07443', '0.06986', '0.06944', '0.06934']
# degree=2 converged=True  reconstruction_error=11.8711  kappa_fit=2.25  refine_iters_run=6  rms_frac_history=['0.06604', '0.06024', '0.05944', '0.05918', '0.05907', '0.05901']
# degree=3 converged=True  reconstruction_error=11.6485  kappa_fit=3.67  refine_iters_run=6  rms_frac_history=['0.06526', '0.05930', '0.05850', '0.05827', '0.05815', '0.05810']

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(results[0].result_.a[1000], label="aia")
plt.plot(results[2].result_.a[1000], label="second order")
plt.grid()
plt.legend()

plt.subplot(122)
plt.plot(results[0].result_.b[1000])
plt.plot(results[2].result_.b[1000])
plt.grid()

plt.tight_layout()

# %%
num_range = np.arange(start=5, stop=20)
iters = 30
tol = 1e-4
refine_iters = 20
refine_tol = 1e-4

cfg_d = PhaseConfig.from_yaml("phase_config.yaml")
cfg_d.use_alpha = True
cfg_d.gain_mode = "joint"
cfg_d.method_kwargs.update(iters=iters, tol=tol, degree=2,
                            refine_iters=refine_iters, refine_tol=refine_tol)

results = {}
for num in num_range:
    solver_d = PhaseSolver(cfg_d)
    solver_d.fit(stack_ref_bright_400_corr[:num])
    results[num] = solver_d
    mp = solver_d.method_param_
    print(f"num={num} converged={mp.refine_converged}  reconstruction_error={solver_d.reconstruction_error_:.4f}  "
            f"kappa_fit={mp.kappa_fit:.3g}  refine_iters_run={mp.refine_iters_run}  "
            f"rms_frac_history={[f'{x:.5f}' for x in mp.rms_frac_history]}")
# Out:
# num=5 converged=True  reconstruction_error=7.7737  kappa_fit=2.36  refine_iters_run=7  rms_frac_history=['0.04372', '0.04061', '0.03948', '0.03891', '0.03866', '0.03854', '0.03848']
# num=6 converged=True  reconstruction_error=8.7140  kappa_fit=2.35  refine_iters_run=6  rms_frac_history=['0.04760', '0.04547', '0.04453', '0.04413', '0.04395', '0.04385']
# num=7 converged=True  reconstruction_error=9.4095  kappa_fit=2.37  refine_iters_run=6  rms_frac_history=['0.05161', '0.04865', '0.04777', '0.04745', '0.04730', '0.04721']
# num=8 converged=True  reconstruction_error=9.8559  kappa_fit=2.3  refine_iters_run=7  rms_frac_history=['0.05897', '0.05253', '0.05041', '0.04977', '0.04952', '0.04939', '0.04933']
# num=9 converged=True  reconstruction_error=10.1818  kappa_fit=2.29  refine_iters_run=7  rms_frac_history=['0.06001', '0.05453', '0.05208', '0.05148', '0.05123', '0.05108', '0.05102']
# num=10 converged=True  reconstruction_error=10.4770  kappa_fit=2.29  refine_iters_run=5  rms_frac_history=['0.05779', '0.05417', '0.05268', '0.05246', '0.05238']
# num=11 converged=True  reconstruction_error=10.7172  kappa_fit=2.27  refine_iters_run=6  rms_frac_history=['0.05752', '0.05465', '0.05386', '0.05365', '0.05354', '0.05347']
# num=12 converged=True  reconstruction_error=10.9475  kappa_fit=2.27  refine_iters_run=5  rms_frac_history=['0.05874', '0.05588', '0.05481', '0.05464', '0.05456']
# num=13 converged=True  reconstruction_error=11.0737  kappa_fit=2.27  refine_iters_run=6  rms_frac_history=['0.06008', '0.05674', '0.05553', '0.05538', '0.05527', '0.05521']
# num=14 converged=True  reconstruction_error=11.1831  kappa_fit=2.27  refine_iters_run=5  rms_frac_history=['0.06227', '0.05694', '0.05599', '0.05579', '0.05572']
# num=15 converged=True  reconstruction_error=11.4003  kappa_fit=2.27  refine_iters_run=7  rms_frac_history=['0.06402', '0.05828', '0.05728', '0.05686', '0.05675', '0.05676', '0.05673']
# num=16 converged=True  reconstruction_error=11.5096  kappa_fit=2.27  refine_iters_run=5  rms_frac_history=['0.06405', '0.05860', '0.05760', '0.05734', '0.05726']
# num=17 converged=True  reconstruction_error=11.6043  kappa_fit=2.26  refine_iters_run=5  rms_frac_history=['0.06461', '0.05904', '0.05804', '0.05780', '0.05773']
# num=18 converged=True  reconstruction_error=11.7191  kappa_fit=2.24  refine_iters_run=5  rms_frac_history=['0.06485', '0.05945', '0.05861', '0.05838', '0.05830']
# num=19 converged=True  reconstruction_error=11.7786  kappa_fit=2.25  refine_iters_run=6  rms_frac_history=['0.06538', '0.05974', '0.05890', '0.05873', '0.05862', '0.05858']

# %%
plt.plot(num_range+1, [results[num].method_param_.rms_frac for num in num_range])
plt.hlines(noise_floor_ref_bright_400, 5, 20, color='k', linestyles='--')
plt.text(8,0.059, "Noise floor")
# Out:
# Text(8, 0.059, 'Noise floor')

# %%
from phase.methods.step_field import _poly_basis

degree = 3                                        # pick which results[...] fit to inspect
r = results[degree].result_
mp = results[degree].method_param_
a_, b_, phi_ = r.a, r.b, r.phi
u_ = b_ * np.cos(phi_)
v_ = -b_ * np.sin(phi_)

i = a_.size // 2                                  # a pixel index (flat)
row, col = np.unravel_index(i, a_.shape)
u_i, v_i = u_[row, col], v_[row, col]
b_i = np.hypot(u_i, v_i)

# The degree-2 model's actual per-frame step AT THIS PIXEL, not the plain
# piston delta -- delta_n(x,y) = delta_n + coeffs[:,n] @ basis(x,y)
# (docs/step_field_residuals.md Eq. T1), evaluated at (row, col) only (no
# need to build the full (N,H,W) field for one pixel).
basis = _poly_basis(*a_.shape, degree, np)        # (J, P)
basis_i = basis[:, i]                             # (J,) -- this pixel's basis values
delta_eff = r.delta + mp.coeffs.T @ basis_i        # (N,) -- this pixel's true step

xn = u_i * np.cos(delta_eff) + v_i * np.sin(delta_eff)   # fitted x_n, degree-2 model
yn = u_i * np.sin(delta_eff) - v_i * np.cos(delta_eff)   # quadrature

# Raw experimental x_n at the same pixel, alpha/g-corrected the same way the
# model is (I_n = alpha_n*(a + g_n*(u*cos(delta_n)+v*sin(delta_n)))) -- paired
# with the *model's* yn, since a single-channel intensity sample only gives
# one real number per frame, not an independent (x,y) pair. Points straying
# off the fitted circle are frames where the raw data disagrees with what
# the degree-2 fit predicts -- this is the actual "how good is my model"
# check, now that the reference uses the fitted step field, not the piston.
xn_raw = (stack_ref_bright_400_corr[:, row, col] / r.alpha - a_[row, col]) / r.g

theta = np.linspace(0, 2 * np.pi, 400)
plt.plot(b_i * np.cos(theta), b_i * np.sin(theta), '-', color='0.7', lw=1,
         label='ideal circle (radius b)')
plt.plot(xn, yn, 'o', label=f'fitted (degree={degree})')
plt.plot(xn_raw, yn, 'x', label='raw data')
plt.gca().set_aspect('equal')
plt.xlabel('x_n')
plt.ylabel('y_n')
plt.title(f'Lissajous ellipse at one pixel (degree={degree})')
plt.legend()

# %%
xr, yr = xn_raw, yn          # yr still comes from the model -- see the note in the cell above
th = np.arctan2(yr, xr)
rad = np.hypot(xr, yr)

print("radial scatter (amp err):", np.std(rad) / b_i)                # alpha/g miscalibration, noise
print("angular scatter (delta err):", np.std(wrap(th - delta_eff)))  # phase-step (delta_n) error
# Out:
# radial scatter (amp err): 0.05136305878456659
# angular scatter (delta err): 0.04779927826426267

# %%
plt.imshow(results[3].result_.b/results[3].result_.a)
# plt.xlim([500, 1500])
# plt.ylim([1750, 1250])

# %%
plt.plot(results[3].result_.delta, '.-')

# %%
results[3].method_param_
# Out:
# StepFieldParam(aia_param=AIAParam(kappa_p=2.8191986794594732, kappa_ps=2.000810119631153, predicted_rms=np.float64(0.03620804055289385), iters_run=4, converged=True, g_fit=array([1.00105167, 1.00539533, 1.0087526 , 1.01260055, 1.00732579,
#        0.90239437, 1.0003711 , 0.99780914, 0.97206278, 0.99720152,
#        1.00586906, 1.0000571 , 0.99489988, 0.99376884, 0.99713277,
#        1.00585703, 1.00264399, 0.9999429 , 0.99350416, 0.99797977]), c_fit=array([-0.03129171, -0.01308825,  0.01523654,  0.04844011, -0.03533833,
#         0.00528066,  0.00190005,  0.03728567, -0.08160314,  0.02658717,
#        -0.01206635,  0.03662111, -0.02396854,  0.05340033, -0.04052169,
#        -0.00863938,  0.01641824,  0.01292168, -0.06248158,  0.05490739]), g_min_ratio=0.9023943673684416), degree=3, coeffs=array([[ 1.41616041e+02, -3.78036984e+01,  1.66229444e+02,
#          1.56567386e+02,  1.10277530e+02, -6.35276717e+01,
#         -3.98632902e+02,  2.92540159e+02,  5.30049380e+02,
#          4.09246692e+02,  6.77578227e+01, -3.30313745e+02,
#         -1.91542939e+02, -1.13084147e+02,  3.98655339e+02,
#         -7.46484071e+01, -1.42095610e+02, -5.13143267e+01,
#         -4.08772775e+02, -4.44860009e+02],
#        [ 8.82285541e+01,  9.67877237e+01, -5.30862197e+01,
#         -3.48963030e+01, -1.37858072e+02, -2.51966673e+01,
#          5.18041806e+01,  3.00067469e+02,  6.11981801e+01,
#          1.57356330e+01, -3.70740196e+02, -1.56303819e+02,
#          2.21651073e+02,  3.01588286e+02, -6.82944363e+01,
#         -2.11099844e+02,  1.00323327e+02, -8.34755967e+01,
#         -1.67230904e+02,  4.27881348e+01],
#        [-2.80053456e+01, -9.62392099e+01,  4.47847806e+01,
#          1.67368329e+02,  9.24187922e+01,  1.10078936e+02,
#          7.77994298e+01,  1.69258665e+02,  5.62442998e+00,
#         -1.19370818e+02, -1.55038848e+01,  1.25203288e+02,
#         -9.97490435e+01, -2.72355497e+02, -2.84516258e+01,
#         -1.58749085e+01, -2.40657588e+02, -1.62976557e+01,
#          1.01979469e+02,  4.66268873e+01],
#        [-3.00167842e+00, -5.46697770e+01,  3.92145137e+01,
#         -3.55133851e+01,  6.29633743e+00, -6.07727674e+01,
#         -4.00616510e+01,  4.33013691e+01, -1.62137634e+01,
#          7.75365331e+01,  1.24386171e+01,  1.05182968e+01,
#         -3.76589182e+01,  2.03587767e+01, -2.25413077e+01,
#         -2.73910807e+01,  6.90185185e+00,  3.81305969e+01,
#          6.59985091e+00,  2.28333600e+01],
#        [-4.68106662e+01, -3.03839251e+01,  3.32618993e+01,
#          5.12374044e+01,  6.37424564e+01,  9.86851127e+00,
#         -2.32678844e+01,  1.22294612e+02,  2.80575633e+01,
#         -5.65960382e+00, -4.94445754e+00, -6.15481788e+00,
#         -4.16531378e+01, -6.93969902e+01,  1.40885717e+01,
#          3.32473931e+01, -6.11946900e+01, -2.24828879e+01,
#         -1.57217711e+01, -1.70865701e+01],
#        [-3.22719713e+01,  3.45009416e+00,  1.45314796e+00,
#         -3.58010807e+00, -6.57863010e+01,  6.98726587e+00,
#          4.56908945e+01, -1.21362736e+01, -1.04896185e+01,
#         -1.07044371e+01, -2.63510387e+00,  6.92023870e+00,
#          5.44926680e+01,  2.01853562e+01, -7.01091707e+01,
#          2.57495511e+01,  3.56579208e+01, -2.29872969e+01,
#          6.69069654e-01,  2.80220242e+01],
#        [ 1.09056495e+01, -3.49198769e+01,  8.28747207e+00,
#          4.38036506e+00,  3.01092283e+01, -1.13774721e+00,
#         -6.66672996e+00, -4.43583208e+01, -1.57222148e+01,
#         -2.31660009e+01,  4.00428855e+01,  5.71023461e+01,
#         -1.27689302e+01, -1.46852237e+01, -2.12364477e+01,
#          2.32130756e+01, -7.17364226e+00, -1.16492288e+01,
#          8.51676024e+00,  1.17989280e+01],
#        [-2.92694654e+00, -1.67487399e+01,  1.50697201e+01,
#         -1.16978340e+00, -8.59287073e+00, -1.60604083e+01,
#          2.38759190e+01, -1.69237837e+01,  4.19357537e+00,
#         -7.42831929e+00,  6.34512709e+00,  1.34045640e+01,
#          1.46426650e+01, -8.97660109e+00, -2.14427319e+01,
#          2.45727281e+01,  9.66666303e+00, -2.32259102e+01,
#          9.68986522e+00,  1.87998462e+00],
#        [ 1.13366552e+01, -8.34243019e+00,  2.40864830e+00,
#          1.09969521e+01,  6.79113554e-01, -1.53351014e+01,
#         -4.66270870e-01, -1.81068481e+01,  5.68005409e+00,
#          1.22119320e+00,  2.96943374e+00,  1.71697913e+01,
#         -7.02887052e+00, -6.35913706e+00,  6.30656982e+00,
#          4.21891343e-01, -4.31724753e-01,  2.23489793e+00,
#          6.02820221e+00, -5.44158126e+00]]), coeffs_rms=array([273.70086233, 163.64073996, 118.6519478 ,  35.14782975,
#         44.73795233,  31.22514067,  24.25033979,  14.29584042,
#          8.44645359]), kappa_fit=3.6653385264565226, rms_frac=0.05810434261462553, rms_frac_history=[0.06525548730033463, 0.05929639180547214, 0.05850475740987042, 0.058265643438720094, 0.058153845564927135, 0.05810434261462553], refine_iters_run=6, refine_converged=True, best_iter=5)

# %%
plt.plot(stack_ref_bright_400_corr[0,1000])
plt.plot(stack_ref_bright_400_corr[5,1000])
